# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Mengambil semua ulasan dari aplikasi dengan ID 'com.tokopedia.tkpd' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.tokopedia.tkpd',  # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=10000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
import csv
# Menyimpan ulasan dalam file CSV
with open('ulasan_aplikasi_tokopedia.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd
df = pd.read_csv('ulasan_aplikasi_tokopedia.csv')
df.head()
# Out:
#                                               Review
# 0  Customer servicenya lamaaaaa sekali, sering ng...
# 1  Tidak memuaskan untuk pengalaman pembelian, kn...
# 2  costumer service nya lama menanggapi dan selal...
# 3  Waduhh semakin lama Tokopedia semakin jelek, t...
# 4  Sejak update, sekarang tidak lagi terlihat kap...

# %%
df.shape
# Out:
# (261000, 1)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi_tokopedia.csv', index=False)

# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  79849fa9-faad-4368-b7f4-27e6d4f7a6ce  Pengguna Google
# 1  792583ee-ea0f-47ec-bede-69a90378d117  Pengguna Google
# 2  16ae41f6-1f0a-47a5-b2e6-9fd235c87a72  Pengguna Google
# 3  d9e42b4c-41ca-4620-a01f-d96fa1e181b4  Pengguna Google
# 4  e3a40458-3de7-4ee4-a6e6-947199a50124  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Customer servicenya lamaaaaa sekali, sering ng...      1             35
# 1  Tidak memuaskan untuk pengalaman pembelian, kn...      1             10
# ...
